# %% [markdown]
# Sum of two numbers

# %%
x = 2
y = 6
x+y
# Out:
# 8

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(start=-10, stop=10, num=100)
y = np.sin(x)

plt.plot(x, y)
plt.show()
